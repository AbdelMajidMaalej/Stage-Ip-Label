# %%
from Reward import get_reward
website_url = "https://www.ip-label.fr/formulaire-contact" 
get_reward(website_url)
# Out:
# Current working directory: C:\Users\ASUS\Documents\Stage
# Error executing Locust: [2023-08-21 14:20:15,648] DESKTOP-FQ3N7T7/INFO/locust.main: Run time limit set to 30 seconds
# [2023-08-21 14:20:15,648] DESKTOP-FQ3N7T7/INFO/locust.main: Starting Locust 2.15.1
# Type     Name                                                                          # reqs      # fails |    Avg     Min     Max    Med |   req/s  failures/s
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
# --------|----------------------------------------------------------------------------|-------|-------------|-------|-------|-------|-------|--------|-----------
#          Aggregated                                                                         0     0(0.00%) |      0       0       0      0 |    0.00        0.00
#
# ...
